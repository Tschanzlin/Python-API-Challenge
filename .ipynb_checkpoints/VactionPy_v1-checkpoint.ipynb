# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
# Store filepath, load the csv file
input_file = "full_output.csv"
input_df = pd.read_csv(input_file)

# %%
input_df.head()
# Out:
#          City  Longitude  Latitude  Tempurature (F)  Humidity  \
# 0      dikson      80.55     73.51            41.38        87
# 1  georgetown     100.34      5.41            84.09        74
# 2      hasaki     140.83     35.73            74.75        94
# 3      albany     -73.97     42.60            71.29        75
# 4    victoria     114.16     22.29            85.39        58
#
#    Windspeed (MPH)  Cloudiness
# 0            17.13           1
# 1             6.93          20
# 2             5.82          75
# 3             3.13          49
# 4            11.01          98

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Access gmaps 
gmaps.configure(api_key=g_key)

# Customize the size of the figure
figure_layout = {
    'width': '1000px',
    'height': '800px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=figure_layout)

# Establish coordinates from long / data; assign markers and layer to the map
lats = input_df["Latitude"]
lngs = input_df["Longitude"]
coordinates = zip(lats, lngs)

markers = gmaps.marker_layer(list(coordinates))

fig.add_layer(markers)

fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='800px', margin='0 auto 0 auto', padding='1px', wi…

# %%
# Add the heat layer

#humidity = input_df["Humidity"]

#fig = gmaps.figure()
#locations = humidity
#heatmap = gmaps.heatmap_layer(humidity)
#heatmap.max_intensity = 2
#heatmap.point_radius = 3
#heatmap.gradient = ['white', 'gray']
#fig.add_layer(heatmap)

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
ideal_df = input_df.loc[(input_df["Tempurature (F)"] <= 80) & (input_df["Tempurature (F)"] >= 60) & 
                       (input_df["Humidity"] <= 60)]
ideal_df
# Out:
#               City  Longitude  Latitude  Tempurature (F)  Humidity  \
# 19  saint-philippe      55.77    -21.36            63.82        52
# 35           opuwo      13.84    -18.06            76.55        18
#
#     Windspeed (MPH)  Cloudiness
# 19            23.04          75
# 35             9.84           0

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
# NOTE:  Change file to ideal; running on input to have enough city names now to find a hotel


lats1 = input_df["Latitude"]
longs1 = input_df["Longitude"]
# lat_lngs1 = zip(lats1, longs1)

hotels =[]

# list(lat_lngs1)

# "location": target_coordinates,

# coords = [[lats1], [longs1]]
# coords_df = pd.DataFrame(coords)

#for n in longs1:
    #print(coords_df.loc["Latitude"][n])
#    print(n)




for n in np.arange(0,37):
    target_coordinates = str(lats1[n])+","+str(longs1[n])
    print(target_coordinates)
    radius = "5000"
    type = "lodging"

    # build query url
    # query_url = url + "appid=" + api_key + "&q=" + city
    # base url
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"
    query_url = base_url + "location=" + target_coordinates + "&radius=" + radius + "&type=" + type +"&key=" + g_key
    print(query_url)
    
    # run a request using our params dictionary
    response = requests.get(query_url)
    print(response.status_code)
    
    # format response
    hotel_json = response.json()
   

    if hotel_json["status"] == "ZERO_RESULTS":
        hotels.append("No hotels")
    
    else:
        print(hotel_json["status"])
        hotel = hotel_json["results"][0]["name"]
        hotels.append(hotel)
        print(hotel)
  
    
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-33.8670522,151.1957362
#    &radius=1500&type=restaurant&keyword=cruise&key=YOUR_API_KEY
# Out:
# 73.51,80.55
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=73.51,80.55&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# 5.41,100.34
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=5.41,100.34&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Cititel Penang
# 35.73,140.83
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=35.73,140.83&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Inubosaki Kanko Hotel
# 42.6,-73.97
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=42.6,-73.97&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# 22.29,114.16
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=22.29,114.16&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Mini Hotel Central
# 47.91,106.88
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=47.91,106.88&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# The Blue Sky Hotel and Tower
# -23.12,-134.97
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-23.12,-134.97&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Pension Maro'i
# -24.87,113.63
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-24.87,113.63&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Hospitality Carnarvon
# 66.32,-179.17
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=66.32,-179.17&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# 11.67,92.75
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=11.67,92.75&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Fortune Resort Bay Island
# 19.55,-88.68
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=19.55,-88.68&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# 30.48,-115.95
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=30.48,-115.95&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Old Mill Hotel
# 60.72,-46.03
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=60.72,-46.03&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Hotel Qaqortoq
# 57.05,-135.33
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=57.05,-135.33&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Westmark Sitka
# -38.0,-57.56
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-38.0,-57.56&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Gran Hotel Mar del Plata habitaciones
# 68.22,-135.01
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=68.22,-135.01&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Aklavik Inn
# 66.42,112.4
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=66.42,112.4&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Gostinitsa Vilyuy
# -21.21,-159.78
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-21.21,-159.78&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Paradise Inn
# -54.8,-68.3
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-54.8,-68.3&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Albatros Hotel
# -21.36,55.77
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-21.36,55.77&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Chambres d'hôte "La Trinité"
# -21.04,-57.87
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-21.04,-57.87&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Hotel Fuerte Olimpo
# -33.65,115.33
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-33.65,115.33&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Observatory Guest House
# -3.48,23.43
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-3.48,23.43&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# -22.97,-42.03
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-22.97,-42.03&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Pousada Porto Praia
# -30.18,-50.21
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-30.18,-50.21&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Novomar Pousada e Turismo Ltda
# 3.07,172.79
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=3.07,172.79&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Isles Sunset Lodge
# -3.43,10.66
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-3.43,10.66&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# LIKWALE LODGE
# 14.28,74.45
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=14.28,74.45&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Hotel Sagar Residency
# 43.37,-124.22
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=43.37,-124.22&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Best Western Holiday Hotel
# -37.83,140.77
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-37.83,140.77&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Southgate Motel
# -16.48,-151.75
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-16.48,-151.75&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Bora-Bora Pearl Beach Resort & Spa
# 18.37,-65.72
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=18.37,-65.72&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Yunque Mar Beach Hotel
# -42.78,147.06
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-42.78,147.06&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# The Shingles Riverside Cottages
# 59.64,-151.55
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=59.64,-151.55&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Beluga Lake Lodge
# 46.42,3.91
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=46.42,3.91&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Manoir Du Bonheur
# -18.06,13.84
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-18.06,13.84&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# ABBA Guesthouse
# -9.8,-139.03
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-9.8,-139.03&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Villa Enata

# %%
print(hotels)
# Out:
# ['No hotels', 'Cititel Penang', 'Inubosaki Kanko Hotel', 'No hotels', 'Mini Hotel Central', 'The Blue Sky Hotel and Tower', "Pension Maro'i", 'Hospitality Carnarvon', 'No hotels', 'Fortune Resort Bay Island', 'No hotels', 'Old Mill Hotel', 'Hotel Qaqortoq', 'Westmark Sitka', 'Gran Hotel Mar del Plata habitaciones', 'Aklavik Inn', 'Gostinitsa Vilyuy', 'Paradise Inn', 'Albatros Hotel', 'Chambres d\'hôte "La Trinité"', 'Hotel Fuerte Olimpo', 'Observatory Guest House', 'No hotels', 'Pousada Porto Praia', 'Novomar Pousada e Turismo Ltda', 'Isles Sunset Lodge', 'LIKWALE LODGE', 'Hotel Sagar Residency', 'Best Western Holiday Hotel', 'Southgate Motel', 'Bora-Bora Pearl Beach Resort & Spa', 'Yunque Mar Beach Hotel', 'The Shingles Riverside Cottages', 'Beluga Lake Lodge', 'Manoir Du Bonheur', 'ABBA Guesthouse']

# %%
hotel_df = pd.DataFrame({"Hotels": hotels})
hotel_df = pd.concat([hotels_df, input_df], axis =1)
#schoolsum_df = pd.concat([schooltype_df, maingroup_df, budperstu_df, Trial1out_df, Trial2out_df, Trial3out_df], axis=1)
# hotels_df = hotels_df.loc[hotels_df["Hotels"] != "No hotels"]
hotel_df
# Out:
#                                    Hotels             City  Longitude  \
# 0                               No hotels           dikson      80.55
# 1                          Cititel Penang       georgetown     100.34
# 2                   Inubosaki Kanko Hotel           hasaki     140.83
# 3                               No hotels           albany     -73.97
# 4                      Mini Hotel Central         victoria     114.16
# 5            The Blue Sky Hotel and Tower      ulaanbaatar     106.88
# 6                          Pension Maro'i          rikitea    -134.97
# 7                   Hospitality Carnarvon        carnarvon     113.63
# 8                               No hotels        egvekinot    -179.17
# 9               Fortune Resort Bay Island       port blair      92.75
# 10                              No hotels        chunhuhub     -88.68
# 11                         Old Mill Hotel      san quintin    -115.95
# 12                         Hotel Qaqortoq         qaqortoq     -46.03
# 13                         Westmark Sitka            sitka    -135.33
# 14  Gran Hotel Mar del Plata habitaciones    mar del plata     -57.56
# 15                            Aklavik Inn          aklavik    -135.01
# 16                      Gostinitsa Vilyuy         udachnyy     112.40
# 17                           Paradise Inn           avarua    -159.78
# 18                         Albatros Hotel          ushuaia     -68.30
# 19           Chambres d'hôte "La Trinité"   saint-philippe      55.77
# 20                    Hotel Fuerte Olimpo    fuerte olimpo     -57.87
# 21                Observatory Guest House        busselton     115.33
# 22                              No hotels            lodja      23.43
# 23                    Pousada Porto Praia  arraial do cabo     -42.03
# 24         Novomar Pousada e Turismo Ltda         cidreira     -50.21
# 25                     Isles Sunset Lodge       butaritari     172.79
# 26                          LIKWALE LODGE          mayumba      10.66
# 27                  Hotel Sagar Residency          honavar      74.45
# 28             Best Western Holiday Hotel         coos bay    -124.22
# 29                        Southgate Motel    mount gambier     140.77
# 30     Bora-Bora Pearl Beach Resort & Spa           faanui    -151.75
# 31                 Yunque Mar Beach Hotel         luquillo     -65.72
# 32        The Shingles Riverside Cottages      new norfolk     147.06
# 33                      Beluga Lake Lodge            homer    -151.55
# 34                      Manoir Du Bonheur   saint-francois       3.91
# 35                        ABBA Guesthouse            opuwo      13.84
# 36                            Villa Enata           atuona    -139.03
#
#     Latitude  Tempurature (F)  Humidity  Windspeed (MPH)  Cloudiness  \
# 0      73.51            41.38        87            17.13           1
# 1       5.41            84.09        74             6.93          20
# 2      35.73            74.75        94             5.82          75
# 3      42.60            71.29        75             3.13          49
# 4      22.29            85.39        58            11.01          98
# 5      47.91            60.80        87             4.47          75
# 6     -23.12            69.55        79            21.39          28
# 7     -24.87            62.60        93             5.82           0
# 8      66.32            48.52        86             5.21         100
# 9      11.67            84.18        75             1.63          11
# 10     19.55            78.06        87             2.77          93
# 11     30.48            64.27        84             6.93          98
# 12     60.72            50.00        81             9.17          75
# 13     57.05            55.40        87             6.93          90
# 14    -38.00            39.51        86             5.82           0
# 15     68.22            53.60        76             3.36          75
# 16     66.42            55.40        87             8.95          90
# 17    -21.21            69.80        77             9.17          79
# 18    -54.80            26.60        86            24.16          75
# 19    -21.36            63.82        52            23.04          75
# 20    -21.04            57.11        65             8.28         100
# 21    -33.65            61.23        72            17.76         100
# 22     -3.48            95.99        23             4.07          34
# 23    -22.97            76.23        61            12.75           0
# 24    -30.18            51.01        87            16.84         100
# 25      3.07            83.46        72            16.80           1
# 26     -3.43            76.77        66             6.51          86
# 27     14.28            80.44        80             7.70         100
# 28     43.37            51.03        93             9.17           1
# 29    -37.83            42.80        93             3.85           0
# 30    -16.48            77.27        78            14.27           0
# 31     18.37            85.33        66             6.93           1
# 32    -42.78            41.00        87             2.68          87
# 33     59.64            51.21        87             3.36          90
# 34     46.42            82.40        34             5.82         100
# 35    -18.06            76.55        18             9.84           0
# 36     -9.80            78.93        78            21.74           4
#
#                City  Longitude  Latitude  Tempurature (F)  Humidity  \
# 0            dikson      80.55     73.51            41.38        87
# 1        georgetown     100.34      5.41            84.09        74
# 2            hasaki     140.83     35.73            74.75        94
# 3            albany     -73.97     42.60            71.29        75
# 4          victoria     114.16     22.29            85.39        58
# 5       ulaanbaatar     106.88     47.91            60.80        87
# 6           rikitea    -134.97    -23.12            69.55        79
# 7         carnarvon     113.63    -24.87            62.60        93
# 8         egvekinot    -179.17     66.32            48.52        86
# 9        port blair      92.75     11.67            84.18        75
# 10        chunhuhub     -88.68     19.55            78.06        87
# 11      san quintin    -115.95     30.48            64.27        84
# 12         qaqortoq     -46.03     60.72            50.00        81
# 13            sitka    -135.33     57.05            55.40        87
# 14    mar del plata     -57.56    -38.00            39.51        86
# 15          aklavik    -135.01     68.22            53.60        76
# 16         udachnyy     112.40     66.42            55.40        87
# 17           avarua    -159.78    -21.21            69.80        77
# 18          ushuaia     -68.30    -54.80            26.60        86
# 19   saint-philippe      55.77    -21.36            63.82        52
# 20    fuerte olimpo     -57.87    -21.04            57.11        65
# 21        busselton     115.33    -33.65            61.23        72
# 22            lodja      23.43     -3.48            95.99        23
# 23  arraial do cabo     -42.03    -22.97            76.23        61
# 24         cidreira     -50.21    -30.18            51.01        87
# 25       butaritari     172.79      3.07            83.46        72
# 26          mayumba      10.66     -3.43            76.77        66
# 27          honavar      74.45     14.28            80.44        80
# 28         coos bay    -124.22     43.37            51.03        93
# 29    mount gambier     140.77    -37.83            42.80        93
# 30           faanui    -151.75    -16.48            77.27        78
# 31         luquillo     -65.72     18.37            85.33        66
# 32      new norfolk     147.06    -42.78            41.00        87
# 33            homer    -151.55     59.64            51.21        87
# 34   saint-francois       3.91     46.42            82.40        34
# 35            opuwo      13.84    -18.06            76.55        18
# 36           atuona    -139.03     -9.80            78.93        78
#
#     Windspeed (MPH)  Cloudiness
# 0             17.13           1
# 1              6.93          20
# 2              5.82          75
# 3              3.13          49
# 4             11.01          98
# 5              4.47          75
# 6             21.39          28
# 7              5.82           0
# 8              5.21         100
# 9              1.63          11
# 10             2.77          93
# 11             6.93          98
# 12             9.17          75
# 13             6.93          90
# 14             5.82           0
# 15             3.36          75
# 16             8.95          90
# 17             9.17          79
# 18            24.16          75
# 19            23.04          75
# 20             8.28         100
# 21            17.76         100
# 22             4.07          34
# 23            12.75           0
# 24            16.84         100
# 25            16.80           1
# 26             6.51          86
# 27             7.70         100
# 28             9.17           1
# 29             3.85           0
# 30            14.27           0
# 31             6.93           1
# 32             2.68          87
# 33             3.36          90
# 34             5.82         100
# 35             9.84           0
# 36            21.74           4

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-464b2b3e63ad> in <module>
#      11 # Store the DataFrame Row
#      12 # NOTE: be sure to update with your DataFrame name
# ---> 13 hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
#      14 locations = hotel_df[["Lat", "Lng"]]
#
# <ipython-input-38-464b2b3e63ad> in <listcomp>(.0)
#      11 # Store the DataFrame Row
#      12 # NOTE: be sure to update with your DataFrame name
# ---> 13 hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
#      14 locations = hotel_df[["Lat", "Lng"]]
#
# KeyError: 'Hotel Name'

# %%
# Add marker layer ontop of heat map


# Display figure
