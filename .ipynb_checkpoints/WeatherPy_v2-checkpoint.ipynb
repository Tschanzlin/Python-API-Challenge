# %%
# Install citipy
# !pip install citipy

# %%
# Import dependendcies
import matplotlib.pyplot as plt
import requests
import json
import pandas as pd
import numpy as np
from scipy.stats import linregress

# from numpy import random

# Pull API key
# from config import api_key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
long_range = (-180, 180)

# %%
##

# %%
# Test city pull

city = citipy.nearest_city(22.99, 120.21)
city.city_name
city.country_code
# Out:
# 'tw'

# %%
# Random Test city pull
# format is (lat, long, rounded to two decimal places)
city = citipy.nearest_city(42.00, 100.00)
city.city_name
# Out:
# 'jiuquan'

# %%
# Create a random number generator to pull city name and lat, long for 500 cities using citipy
    # iterative loop with lists for city name, city lat, city long
# use openweathermap.org to pull weather data for representatitive city
    # research API documentation to understand format to pull for each city
    # single pull after city name list is created?
# read data from JSON file; do this for a single city first

# %%
# Create a random city pull request
# latitude = runs east-west, y-values range between -90 and +90
# longitude = runs north_south, x-coordinates are between -180 and +180


from numpy import random
lat = random.randint(low=-90, high=90, size=1)
long = random.randint(low=-180, high=180, size=1)

int(lat)
# Out:
# -40

# %%
city = citipy.nearest_city(lat, long)
city_out = city.city_name
city_out
# Out:
# 'ribeira grande'

# %%
# Create a single city open weather pull request

# Set API key (Note:  not able to pull from config file)
api_key = weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?"
city = "marcona"

# Build query URL, and print output
query_url = url + "appid=" + api_key + "&q=" + city
print(query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=73f5eef4ab6510912790a3c3d182fec9&q=marcona

# %%
# Get weather datafile
weather_response = requests.get(query_url)
weather_json = weather_response.json()

# Select temperature (F), humidity (%), cloudiness (%), and wind speed (mph) from json
temp = weather_json["main"]["temp"]
humid = weather_json["main"]["humidity"]
clouds = weather_json["clouds"]["all"]
windspd = weather_json["wind"]["speed"]

pd.DataFrame([city_out, temp, humid, clouds, windspd])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-6dd0fc1b1416> in <module>
#       4
#       5 # Select temperature (F), humidity (%), cloudiness (%), and wind speed (mph) from json
# ----> 6 temp = weather_json["main"]["temp"]
#       7 humid = weather_json["main"]["humidity"]
#       8 clouds = weather_json["clouds"]["all"]
#
# KeyError: 'main'

# %%
# Simple loop with ten cities

# Import dependencies
from numpy import random
from numpy import arange

# Set API key (fix to pull from config file)
api_key = weather_api_key

# Initialize lists to store values, set counter range for use in loop:

cities = []
latitude = []
longitude = []
tempurature = []
humidity = []
cloudiness = []
windspeed = []

counter = arange(1,600)
totcount = len(counter)

for count in counter:

    # generate random coordinates for cities, store latitude and longitude
    lat = int(random.randint(low=-90, high=90, size=1))
    long = int(random.randint(low=-180, high=180, size=1))
    


    # find city using citipy, store city
    city = citipy.nearest_city(lat, long)
    city_out = city.city_name
    city_out
    
    
    print("Processing record {0} of {1}:  {2}".format(count, totcount, city_out))

    # Set endoint, build query-url
    url = "http://api.openweathermap.org/data/2.5/weather?"
    query_url = url + "appid=" + api_key + "&q=" + city_out
    
    # Get weather datafile, check response code, if response code !200, then continue
    weather_response = requests.get(query_url)
    
    if weather_response.status_code != 200:
        print(f"{city_out} not found.  Skipping ... ")
        continue
    
    elif weather_response.status_code == 200:
        # if valid repsonse code, append city name, longitude, and latitude
        cities.append(city_out)
        latitude.append(lat)
        longitude.append(long)
        
        
        weather_json = weather_response.json()
        # print(query_url)

        # Select temperature (F), humidity (%), cloudiness (%), and wind speed (mph) from json
        temp = weather_json["main"]["temp"]
        humid = weather_json["main"]["humidity"]
        clouds = weather_json["clouds"]["all"]
        windspd = weather_json["wind"]["speed"]
        
        # print(city_out, long, lat, temp, humid, windspd, clouds)
     

        # store weather data to file
        tempurature.append(temp)
        humidity.append(humid)
        cloudiness.append(clouds)
        windspeed.append(windspd)

        # troubleshoot = {"City":  city_out, "Temp": temp, "Humidity": humid, "Clouds": cloudiness, "Winds": windspeed}
        # print(troubleshoot)

        # print city to create print log for each city
        # print(city_out)

# format output to DataFrame    
output = {"City": cities, "Longitude": longitude, "Latitude": latitude, "Tempurature": tempurature, 
      "Humidity": humidity, "Windspeed": windspeed, "Cloudiness": cloudiness}

# Create a summary reccord of cities and data points found
print(len(cities), len(longitude), len(latitude), len(tempurature), len(humidity), len(cloudiness), len(windspeed))
# Out:
# Processing record 1 of 599:  blagoyevo
# Processing record 2 of 599:  east london
# Processing record 3 of 599:  rikitea
# Processing record 4 of 599:  cape town
# Processing record 5 of 599:  atuona
# Processing record 6 of 599:  east london
# Processing record 7 of 599:  yerbogachen
# Processing record 8 of 599:  ferme-neuve
# Processing record 9 of 599:  mataura
# Processing record 10 of 599:  chuy
# Processing record 11 of 599:  provideniya
# Processing record 12 of 599:  rikitea
# Processing record 13 of 599:  bethel
# Processing record 14 of 599:  hilo
# Processing record 15 of 599:  atuona
# Processing record 16 of 599:  westport
# Processing record 17 of 599:  mandalgovi
# Processing record 18 of 599:  rikitea
# Processing record 19 of 599:  pangnirtung
# Processing record 20 of 599:  qaanaaq
# Processing record 21 of 599:  salalah
# Processing record 22 of 599:  svetlaya
# Processing record 23 of 599:  olafsvik
# Processing record 24 of 599:  la ronge
# Processing record 25 of 599:  mar del plata
# Processing record 26 of 599:  nadym
# Processing record 27 of 599:  suicheng
# Processing record 28 of 599:  butaritari
# Processing record 29 of 599:  hithadhoo
# Processing record 30 of 599:  punta arenas
# Processing record 31 of 599:  carnarvon
# Processing record 32 of 599:  albany
# Processing record 33 of 599:  pevek
# Processing record 34 of 599:  albany
# Processing record 35 of 599:  ushuaia
# Processing record 36 of 599:  muscatine
# Processing record 37 of 599:  mataura
# Processing record 38 of 599:  turbat
# Processing record 39 of 599:  puerto ayora
# Processing record 40 of 599:  provideniya
# Processing record 41 of 599:  port elizabeth
# Processing record 42 of 599:  bambous virieux
# Processing record 43 of 599:  lata
# Processing record 44 of 599:  port alfred
# Processing record 45 of 599:  jamestown
# Processing record 46 of 599:  punta arenas
# Processing record 47 of 599:  ushuaia
# Processing record 48 of 599:  hobart
# Processing record 49 of 599:  nome
# Processing record 50 of 599:  rikitea
# Processing record 51 of 599:  nikolskoye
# Processing record 52 of 599:  madera
# Processing record 53 of 599:  castro
# Processing record 54 of 599:  takoradi
# Processing record 55 of 599:  kloulklubed
# vaitupu not found.  Skipping ...
# Processing record 598 of 599:  cape town
# Processing record 599 of 599:  mataura
# 547 547 547 547 547 547 547

# %%
# Convert to dataframe
output_df = pd.DataFrame(output)
output_df.head()
# Out:
#           City  Longitude  Latitude  Tempurature  Humidity  Windspeed  \
# 0    blagoyevo         48        63       289.88        83       3.80
# 1  east london         44       -58       291.41        50       4.01
# 2      rikitea       -134       -53       292.55        64       7.98
# 3    cape town         -5       -54       286.87        93       1.00
# 4       atuona       -131        -5       299.03        75       9.03
#
#    Cloudiness
# 0          93
# 1           0
# 2           0
# 3           0
# 4           0

# %%
# Review dataframe summary info
output_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 547 entries, 0 to 546
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   City         547 non-null    object
#  1   Longitude    547 non-null    int64
#  2   Latitude     547 non-null    int64
#  3   Tempurature  547 non-null    float64
#  4   Humidity     547 non-null    int64
#  5   Windspeed    547 non-null    float64
#  6   Cloudiness   547 non-null    int64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 30.0+ KB

# %%
# Look at number of unique cities
output_df.nunique()
# Out:
# City           285
# Longitude      280
# Latitude       171
# Tempurature    232
# Humidity        76
# Windspeed      177
# Cloudiness      64
# dtype: int64

# %%
# Identify duplicate cities; from above, I have 547 city values, but only 285 unique cities
# merge_df.loc[merge_df.duplicated(['Mouse ID','Timepoint'])]

output_df.loc[output_df.duplicated("City")]
# Out:
#              City  Longitude  Latitude  Tempurature  Humidity  Windspeed  \
# 5     east london         52       -65       291.41        50       4.01
# 11        rikitea       -126       -55       292.55        64       7.98
# 14         atuona       -146        -6       299.03        75       9.03
# 17        rikitea       -140       -68       292.55        64       7.98
# 33         albany        107       -83       301.32        66       0.89
# ..            ...        ...       ...          ...       ...        ...
# 539    bredasdorp         17       -80       286.15        93       2.10
# 540  punta arenas        -99       -70       277.09        80       6.20
# 543     jamestown        -10       -40       299.80        65       6.70
# 545     cape town        -10       -74       286.87        93       1.00
# 546       mataura       -159       -51       277.04        83       1.34
#
#      Cloudiness
# 5             0
# 11            0
# 14            0
# 17            0
# 33           66
# ..          ...
# 539           0
# 540          40
# 543          20
# 545           0
# 546         100
#
# [262 rows x 7 columns]

# %%
# Reivew some of the identified duplicate cities to confirm duplicate values
output_df.loc[output_df["City"] == "east london"]
# Out:
#             City  Longitude  Latitude  Tempurature  Humidity  Windspeed  \
# 1    east london         44       -58       291.41        50       4.01
# 5    east london         52       -65       291.41        50       4.01
# 265  east london         48       -56       291.41        50       4.01
# 320  east london         41       -51       291.41        50       4.01
#
#      Cloudiness
# 1             0
# 5             0
# 265           0
# 320           0

# %%
# format output to DataFrame
output = {"City": cities, "Latitude": latitude, "Longitude": longitude, "Tempurature": tempurature, 
      "Humidity": humidity, "Cloudiness": cloudiness, "Windspeed": windspeed}

print(len(cities), len(latitude), len(longitude), len(tempurature), len(humidity), len(cloudiness), len(windspeed))
# Out:
# 9 9 9 9 9 9 9

# %%
query_url = url + "appid=" + api_key + "&q=" + "barentsburg"
print(query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=73f5eef4ab6510912790a3c3d182fec9&q=barentsburg
