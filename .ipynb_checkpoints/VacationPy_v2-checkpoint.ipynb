# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
# Store filepath, load the csv file
input_file = "Output Folders/full_output.csv"
input_df = pd.read_csv(input_file)

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
figure_layout = {
    'width': '900px',
    'height': '700px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}

# %%
# Access gmaps 
gmaps.configure(api_key=g_key)

# Customize the size of the figure
figure_layout = {
    'width': '900px',
    'height': '700px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}

fig = gmaps.figure(layout=figure_layout)

# Establish coordinates from long / data; assign markers and layer to the map
lats = input_df["Latitude"]
lngs = input_df["Longitude"]
coordinates = zip(lats, lngs)

markers = gmaps.marker_layer(list(coordinates))

fig.add_layer(markers)

fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='700px', margin='0 auto 0 auto', padding='1px', wi…

# %%
import gmaps.datasets

locations = input_df[["Latitude", "Longitude"]]
weights = input_df["Humidity"]
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(locations, weights=weights))
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
ideal_df = input_df.loc[(input_df["Tempurature (F)"] <= 80) & (input_df["Tempurature (F)"] >= 60) & 
                       (input_df["Humidity"] <= 60)]
ideal_df.head()
# Out:
#                    City  Longitude  Latitude  Tempurature (F)  Humidity  \
# 29            tambopata     -69.18    -12.73            75.20        53
# 52   srednyaya yelyuzan      45.95     53.02            71.01        36
# 110         yellowknife    -114.35     62.46            69.04        49
# 117             iquique     -70.14    -20.22            62.60        59
# 122      guerrero negro    -114.06     27.98            77.32        55
#
#      Windspeed (MPH)  Cloudiness
# 29              4.70          41
# 52              3.71           7
# 110             4.70          20
# 117             6.93          40
# 122            13.96           0

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
# NOTE:  This is a test loop to pull correct values from lats1 and longs 1 in next cell

lats1 = ideal_df["Latitude"]
longs1 = ideal_df["Longitude"]
city1 = ideal_df["City"]

# lats1.index has 74 values starting at 29 (row 0) and ending at 568 (row 73)
    #lats1.index[0]
    #lats1.index[73]
    #len(lats1.index)

#create a loop that return index value for count; y returns the index value
for n in np.arange(0, len(lats1.index)):
    y = lats1.index[n]
    #print(city1[y])

# %%
# NOTE:  Change file to ideal; running on input to have enough city names now to find a hotel

#lats1 = ideal_df["Latitude"]
#longs1 = ideal_df["Longitude"]


hotels =[]
hotelindex = []
citytrack = []

#set arange outstide value to equal to index length of lats1

for n in np.arange(0, len(lats1.index)):
    y = lats1.index[n]
    target_coordinates = str(lats1[y])+","+str(longs1[y])
    print(target_coordinates)
    radius = "5000"
    type = "lodging"

    # build query url
    # From google:
    # base url: "https://maps.googleapis.com/maps/api/place/nearbysearch/json?" + endpoint
    # endpoint: location=-33.8670522,151.1957362&radius=1500&type=restaurant&keyword=cruise&key=YOUR_API_KEY
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"
    query_url = base_url + "location=" + target_coordinates + "&radius=" + radius + "&type=" + type +"&key=" + g_key
    print(query_url)
    
    # run a request using our params dictionary
    response = requests.get(query_url)
    print(response.status_code)
    
    # format response
    hotel_json = response.json()   
    
    if hotel_json["status"] == "ZERO_RESULTS":
        hotels.append("No hotels")
        hotelindex.append(ideal_df["City"].index[n])
        citytrack.append(city1[y])
    
    else:
        print(hotel_json["status"])
        hotel = hotel_json["results"][0]["name"]
        hotels.append(hotel)
        hotelindex.append(ideal_df["City"].index[n])
        citytrack.append(city1[y])
        print(hotel)
        
# NOTE:  Printing selected output values to ensure proper responses in building hotel file
# Out:
# -12.73,-69.18
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-12.73,-69.18&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# 53.02,45.95
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=53.02,45.95&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# 62.46,-114.35
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-25.17,45.05&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# 63.86,57.31
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=63.86,57.31&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Mini-Hotel Lokomotiv
# -29.68,-53.81
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-29.68,-53.81&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Hotel Morotin
# 54.77,38.88
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=54.77,38.88&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Guest House on Krasnoarmeyskaya 46
# 68.75,161.3
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=68.75,161.3&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Gostinitsa
# 55.04,-1.45
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=55.04,-1.45&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Cara Guesthouse
# -14.8,36.54
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-14.8,36.54&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Hotel Vision
# 49.23,-100.06
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=49.23,-100.06&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Boissevain Campgrounds
# 23.85,-104.23
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=23.85,-104.23&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Uraján de Luna Hotel Boutique & SPA
# -20.74,116.85
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-20.74,116.85&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# ibis Styles Karratha
# 69.38,178.42
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=69.38,178.42&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# 40.43,71.72
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.43,71.72&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Ikathouse
# -29.95,-71.34
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-29.95,-71.34&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Hotel San Juan
# -3.7,128.18
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-3.7,128.18&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Swiss-Belhotel Ambon
# 39.74,98.52
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=39.74,98.52&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Jiuquan Hotel
# 47.92,17.98
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=47.92,17.98&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Oáza Camp Komoča
# 50.16,35.53
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=50.16,35.53&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# мотель Сюжет
# -29.94,-51.72
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-29.94,-51.72&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Ilha das Pedras de Triunfo Hotel/RS
# 42.62,-113.68
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=42.62,-113.68&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Uptown Motel
# -22.96,14.51
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-22.96,14.51&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Oyster Box Guesthouse
# 68.05,166.44
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=68.05,166.44&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Gostinitsa Severyanka
# 49.63,-105.98
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=49.63,-105.98&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Canalta Hotel Assiniboia
# -34.62,-68.33
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.62,-68.33&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Hotel San Rafael
# 45.52,-122.68
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=45.52,-122.68&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Portland Marriott City Center
# 44.06,-103.15
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=44.06,-103.15&radius=5000&type=lodging&key=AIzaSyDhUMylx3edToKfFkV2CQLxjkmq0HGbzNw
# 200
# OK
# Fairfield Inn & Suites by Marriott Rapid City

# %%
city = hotel_json["results"][]
# Out:
#   File "<ipython-input-83-331d6421a1a0>", line 1
#     city = hotel_json["results"][]
#                                  ^
# SyntaxError: invalid syntax

# %%
# Format hotels output and set index on ideal_df index
hotelout_df = pd.DataFrame({"Nearest Hotel": hotels, "City": citytrack})
indexout_df = pd.DataFrame({"Index": hotelindex})
hotelsearch_df = pd.concat([hotelout_df, indexout_df], axis=1) 
hotelsearch_df.set_index("Index").head()

# %%
# Merge hotelsearch_df adn ideal_df files
# NOTE:  This took several iterations to get to work, including the following
    # hotel_df = pd.concat([ideal_df, hotelsearch_df], axis=1)
    # hotel_df = pd.DataFrame({"Hotels": hotels})
    # hotel_df = pd.concat([hotel_df, ideal_df], axis =1)
    
hotel_df = pd.merge(ideal_df, hotelsearch_df, on="City")
hotel_df

# %%
# Clean for cities with no hotels:
hotel_df = hotel_df[hotel_df["Nearest Hotel"] != "No hotels"]
hotel_df

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Nearest Hotel}</dd>
<dt>City</dt><dd>{City}</dd>

</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Latitude", "Longitude"]]

# %%
<dt>Country</dt><dd>{Country}</dd>

# %%
# Plot ideal cities on a map
# Access gmaps 
gmaps.configure(api_key=g_key)

# Customize the size of the figure
figure_layout = {
    'width': '1000px',
    'height': '800px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=figure_layout)

# Establish coordinates from long / data; assign markers and layer to the map
lats = hotel_df["Latitude"]
lngs = hotel_df["Longitude"]
coordinates = zip(lats, lngs)

markers = gmaps.marker_layer(list(coordinates))

fig.add_layer(markers)

fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='800px', margin='0 auto 0 auto', padding='1px', wi…
